# %% [markdown]
# https://codeshare.io/kadikoy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["Pregnancies"].max()
# Out:
# np.int64(17)

# %%
df["Pregnancies"].min()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df[df["Outcome"]== 1].sum()
# Out:
# Pregnancies                  1304.000
# Glucose                     37857.000
# BloodPressure               18981.000
# SkinThickness                5940.000
# Insulin                     26890.000
# BMI                          9418.200
# DiabetesPedigreeFunction      147.534
# Age                          9934.000
# Outcome                       268.000
# dtype: float64

# %%
df["Outcome"]== 1
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764    False
# 765    False
# 766     True
# 767    False
# Name: Outcome, Length: 768, dtype: bool

# %%
df[df["Outcome"]== 0] ["Outcome"].count() #hasta olmayanların sayısını verir.
# Out:
# np.int64(500)

# %%
df[df["Outcome"]== 0]  ["BMI"].max()
# Out:
# np.float64(57.3)

# %%
df[df["Outcome"] == 0].sort_values("BMI", ascending=False)["Age"].iloc[0]
# Out:
# np.int64(22)

# %%
df[df["Outcome"]== 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[df["Outcome"] == 0].sort_values("BMI", ascending=False)["Age"].iloc[0]
# Out:
# np.int64(22)

# %%
df[df["Outcome"] == 0].sort_values("BMI", ascending=False) ["Age"].iloc[0]
# Out:
# np.int64(22)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#kan basıncı 50'den büyük olanların en büyük insülün değeri
df[df["BloodPressure"] > 50].sort_values("Insulin", ascending= False)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 13             1      189             60             23      846  30.1
# 228            4      197             70             39      744  36.7
# 247            0      165             90             33      680  52.3
# 584            8      124             76             24      600  28.7
# 409            1      172             68             49      579  42.4
# ..           ...      ...            ...            ...      ...   ...
# 42             7      106             92             18        0  22.7
# 44             7      159             64              0        0  27.4
# 45             0      180             66             39        0  42.0
# 46             1      146             56              0        0  29.7
# 47             2       71             70             27        0  28.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 13                      0.398   59        1
# ...

# %%
df[(df["Glucose"] > 60) & (df["Outcome"] == 1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["Insulin"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Yaşı 30 olanların ortalama insulin değerleri
df[df['Age']==30]['Insulin'].mean()
# Out:
# np.float64(82.66666666666667)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
numeric_cols = df.select_dtypes(exclude='object').columns
n_cols = 4
n_rows = (len(numeric_cols) + n_cols - 1) // n_cols
plt.figure(figsize=(5 * n_cols, 4 * n_rows))
for i, col in enumerate(numeric_cols):#enumarite hem int hem elemanı
    plt.subplot(n_rows, n_cols, i + 1)
    sns.boxplot(y=df[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
for col in df.select_dtypes(include=np.number).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"Outliers in {col}: {outliers.shape[0]}")
# Out:
# Outliers in Pregnancies: 4
# Outliers in Glucose: 5
# Outliers in BloodPressure: 45
# Outliers in SkinThickness: 1
# Outliers in Insulin: 34
# Outliers in BMI: 19
# Outliers in DiabetesPedigreeFunction: 29
# Outliers in Age: 9
# Outliers in Outcome: 0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.shape[0]
# Out:
# 768

# %%
x = df.drop('Outcome', axis=1) #drop çöpe at diyor outcome sutununu komple at
y = df['Outcome'] # bunda hep 0 veya 1 olduğu için sınıflandırma metotlerı

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # sınıfı çağırıyoruz.
x = scaler.fit_transform(x) #standardize ediyoruz eğitmek yok trasform yapıyoz.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train) #denetimli öğrenmede sınıflsndırmadayım.
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score 

y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred) 
recall = recall_score(y_test, y_pred, average='weighted')
precision = precision_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy*100:.2f}%") #METRİKLERE BAKIN
print(f"Recall: {recall*100:.2f}%")
print(f"Precision: {precision*100:.2f}%")
print(f"F1 Score: {f1*100:.2f}%")
# Out:
# Accuracy: 87.01%
# Recall: 87.01%
# Precision: 86.97%
# F1 Score: 86.72%

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91        51
#            1       0.86      0.73      0.79        26
#
#     accuracy                           0.87        77
#    macro avg       0.87      0.84      0.85        77
# weighted avg       0.87      0.87      0.87        77

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=0)#denetimli de her zaman ayrılır.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=57)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=57)

# %%
y_pred_knn = knn_model.predict(x_test)

# %%
accuracy_knn = accuracy_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn, average='weighted')
precision_knn = precision_score(y_test, y_pred_knn, average='weighted')
f1_knn = f1_score(y_test, y_pred_knn, average='weighted')

print(f"KNN Accuracy: {accuracy_knn*100:.2f}%")
print(f"KNN Recall: {recall_knn*100:.2f}%")
print(f"KNN Precision: {precision_knn*100:.2f}%")
print(f"KNN F1 Score: {f1_knn*100:.2f}%")
# Out:
# KNN Accuracy: 80.52%
# KNN Recall: 80.52%
# KNN Precision: 80.33%
# KNN F1 Score: 79.63%

# %%
cm = confusion_matrix(y_test, y_pred_knn)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86        51
#            1       0.79      0.58      0.67        26
#
#     accuracy                           0.81        77
#    macro avg       0.80      0.75      0.76        77
# weighted avg       0.80      0.81      0.80        77

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB #genellikle duygu analizinde kullanılır.bayes ve varyansım duşuk oluşu doğruluğu artırır.

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(x_test)
accuracy_nb = accuracy_score(y_test, y_pred_nb)
recall_nb = recall_score(y_test, y_pred_nb, average='weighted')
precision_nb = precision_score(y_test, y_pred_nb, average='weighted')
f1_nb = f1_score(y_test, y_pred_nb, average='weighted')

print(f"Naive Bayes Accuracy: {accuracy_nb*100:.2f}%")
print(f"Naive Bayes Recall: {recall_nb*100:.2f}%")
print(f"Naive Bayes Precision: {precision_nb*100:.2f}%")
print(f"Naive Bayes F1 Score: {f1_nb*100:.2f}%")
# Out:
# Naive Bayes Accuracy: 79.22%
# Naive Bayes Recall: 79.22%
# Naive Bayes Precision: 78.97%
# Naive Bayes F1 Score: 78.87%

# %%
cm = confusion_matrix(y_test, y_pred_nb)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        48
#            1       0.76      0.66      0.70        29
#
#     accuracy                           0.79        77
#    macro avg       0.78      0.77      0.77        77
# weighted avg       0.79      0.79      0.79        77
